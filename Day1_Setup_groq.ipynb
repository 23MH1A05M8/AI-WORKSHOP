# %% [markdown]
# <a href="https://colab.research.google.com/github/23MH1A05M8/AI-WORKSHOP/blob/main/Day1_Setup_groq.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install groq
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 5.0 MB/s eta 0:00:00
# ...

# %%
import os, getpass
os.environ['GROQ_API_KEY'] = getpass.getpass('Paste your groq API Key: ')
# Out:
# Paste your groq API Key: ··········

# %%
from groq import Groq
import os

client = Groq(api_key=os.environ["GROQ_API_KEY"])

resp = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {
            "role": "user",
            "content": "Explain the 5-Layer AI Skill Pyramid in 4 short bullet points."
        }
    ]
)

print(resp.choices[0].message.content)
# Out:
# The 5-Layer AI Skill Pyramid consists of the following layers:
# * **Foundation**: Basic understanding of math, statistics, and programming.
# * **Tools and Techniques**: Familiarity with AI frameworks, libraries, and tools like TensorFlow or PyTorch.
# * **Application and Skill**: Ability to apply AI concepts to real-world problems and develop specialized skills.
# * **Strategy and Innovation**: High-level understanding of AI strategy, innovation, and research, enabling the development of new AI applications and solutions.
