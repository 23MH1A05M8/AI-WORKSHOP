# %% [markdown]
# <a href="https://colab.research.google.com/github/23MH1A05M8/AI-WORKSHOP/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid describes the essential competencies needed to build and deploy effective AI solutions:
#
# *   **Foundational Layers:** These are the base, covering **Data Acquisition & Preparation** (collecting, cleaning, structuring data) and the selection/training of **Algorithms** (machine learning models).
# *   **Domain Expertise:** Understanding the specific industry, business problem, or scientific field to which AI is being applied, ensuring the solution is relevant and effective.
# *   **AI Engineering:** Focuses on operationalizing AI systems, including deployment, scalability, maintenance, integration, and MLOps practices for real-world use.
# *   **Ethical & Societal Implications:** The top layer addresses responsible AI development, covering fairness, bias, privacy, security, transparency, and the broader societal impact of AI systems.
